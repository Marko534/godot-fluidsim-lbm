# %% [markdown]
# # Data test

# %%
import pandas as pd
import plotly as pl

# %%
df = pd.read_csv("test.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 59 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   time/fps                              55 non-null     float64
#  1   time/process                          55 non-null     float64
#  2   time/physics_process                  55 non-null     float64
#  3   time/navigation_process               55 non-null     float64
#  4   memory/static                         55 non-null     float64
#  5   memory/static_max                     55 non-null     float64
#  6   memory/msg_buf_max                    55 non-null     float64
#  7   object/objects                        55 non-null     float64
#  8   object/resources                      55 non-null     float64
#  9   object/nodes                          55 non-null     float64
#  10  object/orphan_nodes                   55 non-null     float64
# ...
